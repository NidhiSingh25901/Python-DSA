# %% [markdown]
# <a href="https://colab.research.google.com/github/NidhiSingh25901/Python-DSA/blob/main/PatternListstar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(*("***" for i in range(3)), sep="\n")
#this works in unpacking the tuple.
# Out:
# ***
# ***
# ***

# %%
print(["***" for i in range(3)])
#this return in string format
# Out:
# ['***', '***', '***']

# %%
print(("***" for i in range(3)))
#this return as generator object since the for is in tuple which generally prints in string object format.
# Out:
# <generator object <genexpr> at 0x7b16c2d0a080>
