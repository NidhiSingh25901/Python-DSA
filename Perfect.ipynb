# %% [markdown]
# <a href="https://colab.research.google.com/github/NidhiSingh25901/Python-DSA/blob/main/Perfect.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = int(input("Enter Number: "))
n = num
sum=0
for i in range(1,n):
  if(n%i==0):
    sum+=i

if(sum ==num):
  print("Perfect Number")
else:
  print("Not a perfect number")
# Out:
# Enter Number: 6
# Perfect Number
