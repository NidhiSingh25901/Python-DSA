# %% [markdown]
# <a href="https://colab.research.google.com/github/NidhiSingh25901/Python-DSA/blob/main/LinkedListImplementation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Node:
  def __init__(self, value):
    self.value = value
    self.next = None

# %%
class LinkedList:
  def __init__(self, value=None):
    self.head = None
    self.tail = None
    if value is not None:
      new_node = Node(value)
      self.head = new_node
      self.tail = new_node

  def insert_at_beginning(self, value):
    new_node = Node(value)
    if self.head is None:
      self.head = new_node
      self.tail = new_node
    else:
      new_node.next = self.head
      self.head = new_node

  def print_list(self):
    current = self.head
    nodes = []
    while current:
      nodes.append(str(current.value))
      current = current.next
    print(" -> ".join(nodes))

  def insert_at_index(self, value, pos):
    new_Node = Node(value)

    if pos==0:
      new_Node.next = self.head
      self.head = new_Node
      return

    temp = self.head
    current_index = 0

    while temp and current_index <  pos-1:
      temp = temp.next
      current_index += 1 # Corrected increment

    if temp is None and pos > 0:
        print("Index out of bounds.") # Handle case where pos is greater than list length
        return

    new_Node.next = temp.next
    temp.next = new_Node

  def insert_at_end(self, value):
    new_Node = Node(value)

    if self.head is None:
      self.head = new_Node
      return
    else:
      temp = self.head
      while temp.next is not None:
        temp = temp.next

      temp.next = new_Node

  def delete_last_node(self):
    if not self.head:
      return

    if not self.head.next:
      self.head = None
      return

    temp = self.head
    while temp.next.next:
      temp = temp.next
    temp.next = None

  def delete_the_value(self, value):
    if not self.head:
      return

    if self.head.value == value:
      self.head = self.head.next
      return

    temp = self.head
    while temp.next and temp.next.value!= value:
      temp = temp.next

    if temp.next:
      temp.next = temp.next.next

  def reverse_linked_list(self):
    prev = None
    curr = self.head
    while curr:
      nxt = curr.next
      curr.next = prev
      prev = curr
      curr = nxt
    self.head = prev

# %%
newnode_LL = LinkedList(5)
newnode_ll1 = LinkedList(6)

# %%
# Create a new LinkedList instance, optionally with an initial value
my_linked_list = LinkedList()

# Add nodes to the beginning of the list
my_linked_list.insert_at_beginning(10)
my_linked_list.insert_at_beginning(20)
my_linked_list.insert_at_beginning(30)

# Print the linked list to see the added nodes
print("Linked List after insertions:")
my_linked_list.print_list()

my_linked_list.insert_at_index(300,2)

my_linked_list.print_list()

my_linked_list.insert_at_end(55)

my_linked_list.print_list()

my_linked_list.delete_last_node()

my_linked_list.print_list()

my_linked_list.delete_the_value(20)

my_linked_list.print_list()

my_linked_list.reverse_linked_list()

my_linked_list.print_list()
# Out:
# Linked List after insertions:
# 30 -> 20 -> 10
# 30 -> 20 -> 300 -> 10
# 30 -> 20 -> 300 -> 10 -> 55
# 30 -> 20 -> 300 -> 10
# 30 -> 300 -> 10
# 10 -> 300 -> 30

# %% [markdown]
# The nodes are added at the beginning, so `30` is now the head, followed by `20`, and then `10`.
